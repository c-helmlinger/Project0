# %% [markdown]
# # Installation

# %%
#!pip install matplotlib

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# for model building

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.feature_selection import RFE

# for model evaluation

from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # Introduction of Data

# %%
df_origin = pd.read_csv("/Users/jessicazhang/Desktop/dataCleaned.csv")

# %%
df_origin.columns
# Out:
# Index(['Type1', 'Type2', 'Type3', 'Rooms', 'Bathroom', 'Car', 'Landsize',
#        'BuildingArea', 'Distance', 'YearBuilt', 'Price'],
#       dtype='object')

# %%
df_origin.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5268 entries, 0 to 5267
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Type1         5268 non-null   int64
#  1   Type2         5268 non-null   int64
#  2   Type3         5268 non-null   int64
#  3   Rooms         5268 non-null   int64
#  4   Bathroom      5268 non-null   int64
#  5   Car           5268 non-null   int64
#  6   Landsize      5268 non-null   int64
#  7   BuildingArea  5268 non-null   float64
#  8   Distance      5268 non-null   float64
#  9   YearBuilt     5268 non-null   int64
#  10  Price         5268 non-null   int64
# dtypes: float64(2), int64(9)
# memory usage: 452.8 KB

# %%
df_origin.head()
# Out:
#    Type1  Type2  Type3  Rooms  Bathroom  Car  Landsize  BuildingArea  \
# 0      1      0      0      4         3    2      1001        315.00
# 1      1      0      0      5         4    2      1000        324.00
# 2      1      0      0      4         1    1      1000        203.00
# 3      1      0      0      3         1    4      1000         85.00
# 4      1      0      0      2         1    0      1000         81.79
#
#    Distance  YearBuilt    Price
# 0      21.8       2012   990000
# 1      13.7       1950  2600000
# 2      10.7       1960  1920000
# 3       8.2       1930  1575000
# 4      36.9       1980   655000

# %%
df_origin.shape
# Out:
# (5268, 11)

# %%
df_origin.describe()
# Out:
#              Type1        Type2        Type3        Rooms     Bathroom  \
# count  5268.000000  5268.000000  5268.000000  5268.000000  5268.000000
# mean      0.831435     0.079537     0.089028     3.209377     1.658694
# std       0.374403     0.270600     0.284811     0.841994     0.717612
# min       0.000000     0.000000     0.000000     1.000000     1.000000
# 25%       1.000000     0.000000     0.000000     3.000000     1.000000
# 50%       1.000000     0.000000     0.000000     3.000000     2.000000
# 75%       1.000000     0.000000     0.000000     4.000000     2.000000
# max       1.000000     1.000000     1.000000     8.000000     6.000000
#
#                Car     Landsize  BuildingArea     Distance    YearBuilt  \
# count  5268.000000  5268.000000   5268.000000  5268.000000  5268.000000
# mean      1.702923   469.264617    158.306403    10.982536  1960.378322
# std       0.970426   222.585258     86.560294     6.004801    38.936988
# min       0.000000   100.000000     51.000000     1.200000  1196.000000
# 25%       1.000000   267.000000    109.000000     7.000000  1930.000000
# 50%       2.000000   492.500000    138.000000    10.400000  1960.000000
# 75%       2.000000   648.000000    184.000000    13.700000  1995.000000
# max      10.000000  1001.000000   3112.000000    47.300000  2018.000000
#
#               Price
# count  5.268000e+03
# mean   1.171191e+06
# std    6.438934e+05
# min    1.310000e+05
# 25%    7.283750e+05
# 50%    1.000000e+06
# 75%    1.435000e+06
# max    6.400000e+06

# %%
df_origin.corr()
# Out:
#                  Type1     Type2     Type3     Rooms  Bathroom       Car  \
# Type1         1.000000 -0.652847 -0.694291  0.136671  0.067783  0.132832
# Type2        -0.652847  1.000000 -0.091895 -0.134768 -0.052790 -0.131968
# Type3        -0.694291 -0.091895  1.000000 -0.051618 -0.038948 -0.049233
# Rooms         0.136671 -0.134768 -0.051618  1.000000  0.589627  0.340335
# Bathroom      0.067783 -0.052790 -0.038948  0.589627  1.000000  0.271780
# Car           0.132832 -0.131968 -0.049233  0.340335  0.271780  1.000000
# Landsize      0.313631 -0.302575 -0.124810  0.433966  0.197372  0.398471
# BuildingArea  0.089195 -0.096512 -0.025556  0.544157  0.525496  0.266207
# Distance      0.133726 -0.122486 -0.059416  0.164614  0.069602  0.219037
# YearBuilt     0.025864 -0.002046 -0.032057  0.072805  0.235935  0.194377
# Price         0.052545 -0.051926 -0.019738  0.405078  0.436593  0.137674
#
#               Landsize  BuildingArea  Distance  YearBuilt     Price
# Type1         0.313631      0.089195  0.133726   0.025864  0.052545
# Type2        -0.302575     -0.096512 -0.122486  -0.002046 -0.051926
# Type3        -0.124810     -0.025556 -0.059416  -0.032057 -0.019738
# Rooms         0.433966      0.544157  0.164614   0.072805  0.405078
# Bathroom      0.197372      0.525496  0.069602   0.235935  0.436593
# Car           0.398471      0.266207  0.219037   0.194377  0.137674
# Landsize      1.000000      0.310288  0.352840   0.031179  0.223600
# BuildingArea  0.310288      1.000000  0.058570   0.130430  0.457088
# Distance      0.352840      0.058570  1.000000   0.394375 -0.335547
# YearBuilt     0.031179      0.130430  0.394375   1.000000 -0.286517
# Price         0.223600      0.457088 -0.335547  -0.286517  1.000000

# %% [markdown]
# # Analyzing Data

# %% [markdown]
# ### Convert the YearBuilt

# %%
df_origin["YearBuilt"] = 2021 - df_origin["YearBuilt"]
df_origin.head()
# Out:
#    Type1  Type2  Type3  Rooms  Bathroom  Car  Landsize  BuildingArea  \
# 0      1      0      0      4         3    2      1001        315.00
# 1      1      0      0      5         4    2      1000        324.00
# 2      1      0      0      4         1    1      1000        203.00
# 3      1      0      0      3         1    4      1000         85.00
# 4      1      0      0      2         1    0      1000         81.79
#
#    Distance  YearBuilt    Price
# 0      21.8          9   990000
# 1      13.7         71  2600000
# 2      10.7         61  1920000
# 3       8.2         91  1575000
# 4      36.9         41   655000

# %% [markdown]
# ### Outlier detection {Method 1}

# %% [markdown]
# #### Landsize

# %%
print(df_origin["Landsize"].describe())
# Out:
# count    5268.000000
# mean      469.264617
# std       222.585258
# min       100.000000
# 25%       267.000000
# 50%       492.500000
# 75%       648.000000
# max      1001.000000
# Name: Landsize, dtype: float64

# %% [markdown]
# #### Building Area

# %%
print(df_origin["BuildingArea"].describe())
# Out:
# count    5268.000000
# mean      158.306403
# std        86.560294
# min        51.000000
# 25%       109.000000
# 50%       138.000000
# 75%       184.000000
# max      3112.000000
# Name: BuildingArea, dtype: float64

# %% [markdown]
# #### Distance

# %%
print(df_origin["Distance"].describe())
# Out:
# count    5268.000000
# mean       10.982536
# std         6.004801
# min         1.200000
# 25%         7.000000
# 50%        10.400000
# 75%        13.700000
# max        47.300000
# Name: Distance, dtype: float64

# %% [markdown]
# #### YearBuilt

# %%
print(df_origin["YearBuilt"].describe())
# Out:
# count    5268.000000
# mean       60.621678
# std        38.936988
# min         3.000000
# 25%        26.000000
# 50%        61.000000
# 75%        91.000000
# max       825.000000
# Name: YearBuilt, dtype: float64

# %% [markdown]
# ### Method 2: Histogram

# %%
df_origin.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Type1'}>,
#         <AxesSubplot:title={'center':'Type2'}>,
#         <AxesSubplot:title={'center':'Type3'}>],
#        [<AxesSubplot:title={'center':'Rooms'}>,
#         <AxesSubplot:title={'center':'Bathroom'}>,
#         <AxesSubplot:title={'center':'Car'}>],
#        [<AxesSubplot:title={'center':'Landsize'}>,
#         <AxesSubplot:title={'center':'BuildingArea'}>,
#         <AxesSubplot:title={'center':'Distance'}>],
#        [<AxesSubplot:title={'center':'YearBuilt'}>,
#         <AxesSubplot:title={'center':'Price'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# ### Method 3: Other diagrams

# %%
# Boxplot: Example
sns.boxplot(x='YearBuilt',y='Price',data=df_origin)

# comment: from the graph, it shows little correlation
# Out:
# <AxesSubplot:xlabel='YearBuilt', ylabel='Price'>

# %%
# Scatterplot
sns.lmplot(x='Landsize', y='Price', data=df_origin)
sns.lmplot(x='BuildingArea', y='Price', data=df_origin)
sns.lmplot(x='YearBuilt', y='Price', data=df_origin)
sns.lmplot(x='Distance', y='Price', data=df_origin)

# %% [markdown]
# ### Method 4: Formula (Data Size)

# %%
# Checking the percentage of outlier for all the numerical columns
# Formula: x > Q3 + 1.5IQR or x < Q1 -1.5IQR

# Single
# Calculate or Find on the graph
Q1 = df_origin.BuildingArea.quantile(0.25)
Q3 = df_origin.BuildingArea.quantile(0.75)
print("Q1:",Q1)
print("Q3:", Q3)

# IQR (Inter Quatile Range) = Q3 - Q1
IQR = Q3 - Q1

# Limit
Lower_limit = Q1 - 1.5*IQR
Upper_limit = Q3 + 1.5*IQR
print("Lower_limit:", Lower_limit)
print("Upper_limit:", Upper_limit)
# Out:
# Q1: 109.0
# Q3: 184.0
# Lower_limit: -3.5
# Upper_limit: 296.5

# %% [markdown]
# ### Delete outliers

# %%
# (1) Delete outliers using the code? How?

deleted_indices = []
for col in df_origin.columns[6:9]:
    Q1 = df_origin[col].quantile(0.25)
    Q3 = df_origin[col].quantile(0.75)
    print("{}, Q1: {:.2f}, Q3: {:.2f}".format(col, Q1, Q3))
  
    # IQR (Inter Quatile Range) = Q3 - Q1
    IQR = Q3 - Q1

    # Limit
    Lower_limit = Q1 - 1.5*IQR
    Upper_limit = Q3 + 1.5*IQR
    
    Upper_num = (df_origin[df_origin[col] > Upper_limit]).shape[0]
    Lower_num = (df_origin[df_origin[col] < Lower_limit]).shape[0]
    outlier_rate = (Lower_num + Upper_num) / df_origin.shape[0]
    Upper_index = list((df_origin[df_origin[col] > Upper_limit]).index)
    Lower_index = list((df_origin[df_origin[col] < Lower_limit]).index)
    deleted_indices += (Upper_index + Lower_index)
    
    print("Lower_limit:{:.2f}, Upper_limit:{:.2f}, outlier_rate: {:.4f}% \n---\n".format(Lower_limit, Upper_limit, outlier_rate*100))

new_df = df_origin.drop(list(set(deleted_indices)), axis=0)

# (2) After finding the most obvious point on the graph, then you can just delete it on Excel. {Based on this one}
# Out:
# Landsize, Q1: 267.00, Q3: 648.00
# Lower_limit:-304.50, Upper_limit:1219.50, outlier_rate: 0.0000%
# ---
#
# BuildingArea, Q1: 109.00, Q3: 184.00
# Lower_limit:-3.50, Upper_limit:296.50, outlier_rate: 5.2202%
# ---
#
# Distance, Q1: 7.00, Q3: 13.70
# Lower_limit:-3.05, Upper_limit:23.75, outlier_rate: 3.7585%
# ---

# %% [markdown]
# # Read New .csv

# %%
df = pd.read_csv("/Users/jessicazhang/Desktop/data.csv")

# %%
df.shape
# Out:
# (5267, 11)

# %% [markdown]
# # Data Visualisation

# %% [markdown]
# ### Correlation in numeric data

# %% [markdown]
# ##### Method 1: Heatmap

# %%
# General
sns.heatmap(df.corr(), square=True, annot=True, cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
# Pick the top four
# correlation matrix
corrmat = df.corr()
k = 4 # number of variables for heatmap
cols = corrmat.nlargest(k, 'Price')['Price'].index # choose the top four features that have relationship with price
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale = 1.25)
# cmap means the color, annot short for "annotation"
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size':10}, yticklabels=cols, xticklabels=cols.values, cmap="YlGnBu")
plt.show()

# %% [markdown]
# ##### Method 2: pairplot

# %%
# Show correlation
# scatterplot
sns.pairplot(df)

# %% [markdown]
# ##### Method 3: Enlarged scatterplots (x&y)

# %%
# All the columns
for each in df.columns:
    plt.scatter(df[each], df['Price'])
    plt.xlabel(each)
    plt.ylabel("Melbourne Housing Price")
    plt.grid()
    plt.show()

# %% [markdown]
# ### Visualizing the distribution of the numeric features

# %% [markdown]
# ##### Method 1

# %%
sns.distplot(df['Price'])
# Out:
# /Users/jessicazhang/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
# calculate the skewness
print("Skewness: %f" %df['Price'].skew())
# Out:
# Skewness: 2.003863

# %% [markdown]
# ###### Comment: Since Price is slightly right skewed, checking the distribution of transformed Price

# %% [markdown]
# ##### Method 2: Histogram

# %%
df.hist(bins=15)
# Out:
# array([[<AxesSubplot:title={'center':'Type1'}>,
#         <AxesSubplot:title={'center':'Type2'}>,
#         <AxesSubplot:title={'center':'Type3'}>],
#        [<AxesSubplot:title={'center':'Rooms'}>,
#         <AxesSubplot:title={'center':'Bathroom'}>,
#         <AxesSubplot:title={'center':'Car'}>],
#        [<AxesSubplot:title={'center':'Landsize'}>,
#         <AxesSubplot:title={'center':'BuildingArea'}>,
#         <AxesSubplot:title={'center':'Distance'}>],
#        [<AxesSubplot:title={'center':'YearBuilt'}>,
#         <AxesSubplot:title={'center':'Price'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# # Adding Columns

# %% [markdown]
# ## 1. for x5^0.5

# %%
# x5 is the number of bathroom
# Bathroom_sqrt is the result of square of root

df['Bathroom_sqrt'] = np.sqrt(df['Bathroom'])
df.head()
# Out:
#    Type1  Type2  Type3  Rooms  Bathroom  Car  Landsize  BuildingArea  \
# 0      0      0      1      5         2    1       531        1022.0
# 1      1      0      0      3         1    1       532         934.0
# 2      1      0      0      3         1    1       792         792.0
# 3      1      0      0      5         3    2       836         789.0
# 4      1      0      0      3         1    2       713         720.0
#
#    Distance  YearBuilt    Price  Bathroom_sqrt
# 0       5.6       1890  1975000       1.414214
# 1      16.3       1980   580500       1.000000
# 2      12.2       1950  1365000       1.000000
# 3      24.8       2001  1100000       1.732051
# 4       9.2       1950  1903000       1.000000

# %% [markdown]
# ## 2. for x5^2

# %%
# Bathroom_sqr means Bathroom*Bathroom
# pow() means the square
# i.e. pow(4,2) = 4^2 = 16

df['Bathroom_sqr'] = pow(df['Bathroom'],2)
df.head()
# Out:
#    Type1  Type2  Type3  Rooms  Bathroom  Car  Landsize  BuildingArea  \
# 0      0      0      1      5         2    1       531        1022.0
# 1      1      0      0      3         1    1       532         934.0
# 2      1      0      0      3         1    1       792         792.0
# 3      1      0      0      5         3    2       836         789.0
# 4      1      0      0      3         1    2       713         720.0
#
#    Distance  YearBuilt    Price  Bathroom_sqr
# 0       5.6       1890  1975000             4
# 1      16.3       1980   580500             1
# 2      12.2       1950  1365000             1
# 3      24.8       2001  1100000             9
# 4       9.2       1950  1903000             1

# %% [markdown]
# ## 3. for x8^0.5

# %%
# x8 is the building area
# BuildingArea_sqr is the square root.

df['BuildingArea_sqrt'] = np.sqrt(df['BuildingArea'])
df.head()
# Out:
#    Type1  Type2  Type3  Rooms  Bathroom  Car  Landsize  BuildingArea  \
# 0      0      0      1      5         2    1       531        1022.0
# 1      1      0      0      3         1    1       532         934.0
# 2      1      0      0      3         1    1       792         792.0
# 3      1      0      0      5         3    2       836         789.0
# 4      1      0      0      3         1    2       713         720.0
#
#    Distance  YearBuilt    Price  BuildingArea_sqrt
# 0       5.6       1890  1975000          31.968735
# 1      16.3       1980   580500          30.561414
# 2      12.2       1950  1365000          28.142495
# 3      24.8       2001  1100000          28.089144
# 4       9.2       1950  1903000          26.832816

# %% [markdown]
# ## 4. for x8^2

# %%
# BuildingArea_sqr is the square result.

df['BuildingArea_sqr'] = pow(df['BuildingArea'],2)
df.head()
# Out:
#    Type1  Type2  Type3  Rooms  Bathroom  Car  Landsize  BuildingArea  \
# 0      0      0      1      5         2    1       531        1022.0
# 1      1      0      0      3         1    1       532         934.0
# 2      1      0      0      3         1    1       792         792.0
# 3      1      0      0      5         3    2       836         789.0
# 4      1      0      0      3         1    2       713         720.0
#
#    Distance  YearBuilt    Price  BuildingArea_sqr
# 0       5.6       1890  1975000         1044484.0
# 1      16.3       1980   580500          872356.0
# 2      12.2       1950  1365000          627264.0
# 3      24.8       2001  1100000          622521.0
# 4       9.2       1950  1903000          518400.0

# %% [markdown]
# ## 5. for x9^0.5

# %%
# x9 is the distance
# Distance_sqrt is the square root.

df['Distance_sqrt'] = np.sqrt(df['Distance'])
df.head()
# Out:
#    Type1  Type2  Type3  Rooms  Bathroom  Car  Landsize  BuildingArea  \
# 0      0      0      1      5         2    1       531        1022.0
# 1      1      0      0      3         1    1       532         934.0
# 2      1      0      0      3         1    1       792         792.0
# 3      1      0      0      5         3    2       836         789.0
# 4      1      0      0      3         1    2       713         720.0
#
#    Distance  YearBuilt    Price  Distance_sqrt
# 0       5.6       1890  1975000       2.366432
# 1      16.3       1980   580500       4.037326
# 2      12.2       1950  1365000       3.492850
# 3      24.8       2001  1100000       4.979960
# 4       9.2       1950  1903000       3.033150

# %% [markdown]
# ## 6. for x9^2

# %%
# Distance_sqr is the square.

df['Disctance_sqr'] = pow(df['Distance'],2)
df.head()
# Out:
#    Type1  Type2  Type3  Rooms  Bathroom  Car  Landsize  BuildingArea  \
# 0      0      0      1      5         2    1       531        1022.0
# 1      1      0      0      3         1    1       532         934.0
# 2      1      0      0      3         1    1       792         792.0
# 3      1      0      0      5         3    2       836         789.0
# 4      1      0      0      3         1    2       713         720.0
#
#    Distance  YearBuilt    Price  Disctance_sqr
# 0       5.6       1890  1975000          31.36
# 1      16.3       1980   580500         265.69
# 2      12.2       1950  1365000         148.84
# 3      24.8       2001  1100000         615.04
# 4       9.2       1950  1903000          84.64

# %% [markdown]
# ## 7. combination

# %%
# X8 is the building area
# pow() means the square of the number
# i.e. pow(4,2) = 4*4 = 16

df['BuildingArea_sqr'] = pow(df['BuildingArea'],2)
df['Distance_sqr'] = pow(df['Distance'], 2)

df.head()
# Out:
#    Type1  Type2  Type3  Rooms  Bathroom  Car  Landsize  BuildingArea  \
# 0      0      0      1      5         2    1       531        1022.0
# 1      1      0      0      3         1    1       532         934.0
# 2      1      0      0      3         1    1       792         792.0
# 3      1      0      0      5         3    2       836         789.0
# 4      1      0      0      3         1    2       713         720.0
#
#    Distance  YearBuilt    Price  BuildingArea_sqr  Distance_sqr
# 0       5.6       1890  1975000         1044484.0         31.36
# 1      16.3       1980   580500          872356.0        265.69
# 2      12.2       1950  1365000          627264.0        148.84
# 3      24.8       2001  1100000          622521.0        615.04
# 4       9.2       1950  1903000          518400.0         84.64

# %% [markdown]
# # Drop Column

# %%
df = df.drop(['Landsize'], axis=1)
df.head()
# Out:
#    Type1  Type2  Type3  Rooms  Bathroom  Car  BuildingArea  Distance  \
# 0      0      0      1      5         2    1        1022.0       5.6
# 1      1      0      0      3         1    1         934.0      16.3
# 2      1      0      0      3         1    1         792.0      12.2
# 3      1      0      0      5         3    2         789.0      24.8
# 4      1      0      0      3         1    2         720.0       9.2
#
#    YearBuilt    Price  BuildingArea_sqr  Distance_sqr
# 0       1890  1975000         1044484.0         31.36
# 1       1980   580500          872356.0        265.69
# 2       1950  1365000          627264.0        148.84
# 3       2001  1100000          622521.0        615.04
# 4       1950  1903000          518400.0         84.64

# %% [markdown]
# # Spliting into Train and Test Data

# %%
df["YearBuilt"] = 2021 - df["YearBuilt"]
df.head()
# Out:
#    Type1  Type2  Type3  Rooms  Bathroom  Car  BuildingArea  Distance  \
# 0      0      0      1      5         2    1        1022.0       5.6
# 1      1      0      0      3         1    1         934.0      16.3
# 2      1      0      0      3         1    1         792.0      12.2
# 3      1      0      0      5         3    2         789.0      24.8
# 4      1      0      0      3         1    2         720.0       9.2
#
#    YearBuilt    Price  BuildingArea_sqr  Distance_sqr
# 0        131  1975000         1044484.0         31.36
# 1         41   580500          872356.0        265.69
# 2         71  1365000          627264.0        148.84
# 3         20  1100000          622521.0        615.04
# 4         71  1903000          518400.0         84.64

# %%
# Drop the last column
X = df.drop(['Price'], axis = 1)

# %%
X
# Out:
#       Type1  Type2  Type3  Rooms  Bathroom  Car  BuildingArea  Distance  \
# 0         0      0      1      5         2    1        1022.0       5.6
# 1         1      0      0      3         1    1         934.0      16.3
# 2         1      0      0      3         1    1         792.0      12.2
# 3         1      0      0      5         3    2         789.0      24.8
# 4         1      0      0      3         1    2         720.0       9.2
# ...     ...    ...    ...    ...       ...  ...           ...       ...
# 5262      1      0      0      1         1    1          53.0       3.3
# 5263      0      0      1      1         1    1          51.0       1.2
# 5264      1      0      0      2         1    1          51.0       6.6
# 5265      1      0      0      3         1    1          51.0      11.4
# 5266      1      0      0      1         1    1          51.0      14.6
#
#       YearBuilt  BuildingArea_sqr  Distance_sqr
# 0           131         1044484.0         31.36
# 1            41          872356.0        265.69
# 2            71          627264.0        148.84
# 3            20          622521.0        615.04
# 4            71          518400.0         84.64
# ...         ...               ...           ...
# 5262         91            2809.0         10.89
# 5263         21            2601.0          1.44
# 5264         51            2601.0         43.56
# 5265         61            2601.0        129.96
# 5266         31            2601.0        213.16
#
# [5267 rows x 11 columns]

# %%
y = df["Price"]
print(y)
# Out:
# 0       1975000
# 1        580500
# 2       1365000
# 3       1100000
# 4       1903000
#          ...
# 5262     540000
# 5263     370000
# 5264     540000
# 5265     867000
# 5266     380500
# Name: Price, Length: 5267, dtype: int64

# %% [markdown]
# ## Normalization

# %%
from sklearn import preprocessing

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X = min_max_scaler.fit_transform(X)

# %% [markdown]
# ## Model

# %%
# Divide the data into two groups: training set and testing set

# X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=320, test_size=0.27)

# %% [markdown]
# ### K Fold

# %%
from sklearn.model_selection import KFold

# %%
kf = KFold(n_splits=5)
for train_index, test_index in kf.split(X):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y[train_index], y[test_index]
# Out:
# TRAIN: [1054 1055 1056 ... 5264 5265 5266] TEST: [   0    1    2 ... 1051 1052 1053]
# TRAIN: [   0    1    2 ... 5264 5265 5266] TEST: [1054 1055 1056 ... 2105 2106 2107]
# TRAIN: [   0    1    2 ... 5264 5265 5266] TEST: [2108 2109 2110 ... 3158 3159 3160]
# TRAIN: [   0    1    2 ... 5264 5265 5266] TEST: [3161 3162 3163 ... 4211 4212 4213]
# TRAIN: [   0    1    2 ... 4211 4212 4213] TEST: [4214 4215 4216 ... 5264 5265 5266]

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (4214, 11)
# (1053, 11)
# (4214,)
# (1053,)

# %% [markdown]
# ### Linear Regression

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Model Evaluation

# %% [markdown]
# ### Score

# %%
from sklearn.model_selection import cross_val_score

# %%
# (1) Orginal
orginal_score = cross_val_score(model, X_test, y_test, cv=5)
print("Original score:",orginal_score)
# Out:
# Original score: [0.38793377 0.24598445 0.41410552 0.51712411 0.46915419]

# %%
# (2) Drop a column and Add a new column: x8^2
drop_score = cross_val_score(model, X_test, y_test, cv=5)
print("After dropping one column:",drop_score)
# Out:
# After dropping one column: [0.38733962 0.25136348 0.41538295 0.52231204 0.51973449]

# %%
# (3) Drop a column & Feature Engineer (use the combination) 
combined_score = cross_val_score(model, X_test, y_test, cv=5)
print("Combination score:",combined_score)
# Out:
# Combination score: [0.40297053 0.27196173 0.43784199 0.55372859 0.49911831]

# %% [markdown]
# ## Based on the Third Model

# %% [markdown]
# ### Coefficients & RMSE

# %%
# y_pred_class = model.predict(X_test)
model.predict(X_test)
# Out:
# array([788480., 838656., 235520., ..., 573440., 395264.,  98304.])

# %%
y_test
# Out:
# 4214    450000
# 4215    650000
# 4216    639000
# 4217    657000
# 4218    740000
#          ...
# 5262    540000
# 5263    370000
# 5264    540000
# 5265    867000
# 5266    380500
# Name: Price, Length: 1053, dtype: int64

# %%
result = {'prediction':model.predict(X_test)}

# %%
result_file = pd.DataFrame(result)

# %%
result_file.head()
# Out:
#    prediction
# 0    788480.0
# 1    838656.0
# 2    235520.0
# 3    905216.0
# 4    777216.0

# %%
result_file.to_csv("Linear_Regression.csv")

# %% [markdown]
# # Result Visualization

# %%
y_predict = result['prediction']
y_test_arr = np.array(list(y_test))
argsort = np.argsort(list(y_test_arr))
sorted_y_test = y_test_arr[argsort]
sorted_y_predict = y_predict[argsort]

index_x = [w for w in range(len(y_predict))]
plt.figure(figsize=(20,10))
plt.plot(index_x, sorted_y_test)

plt.plot(index_x, sorted_y_predict)
plt.legend(['y_true', 'y_predict'])

# %% [markdown]
# ## Model Comparison

# %%
original_score = [0.38793377, 0.24598445, 0.41410552, 0.51712411, 0.46915419]
drop_score = [0.38733962, 0.25136348, 0.41538295, 0.52231204, 0.51973449]
combined_score = [0.40297053, 0.27196173, 0.43784199, 0.55372859, 0.49911831]

plt.boxplot([original_score, drop_score, combined_score],vert=False,showmeans=True)
plt.xlabel('Scores')
plt.ylabel('Model')
plt.title('Model Comparison')

plt.show()

# %% [markdown]
# ### Comment: Model 3 is the best one.
