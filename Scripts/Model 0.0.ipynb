# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/home/jovyan/demo/melb-data.csv")

# %%
print(df)
# Out:
#       Type1  Type2  Type3  Rooms  Bathroom  Car  Landsize  BuildingArea  \
# 0         1      0      0      4         3    2      1001        315.00
# 1         1      0      0      5         4    2      1000        324.00
# 2         1      0      0      4         1    1      1000        203.00
# 3         1      0      0      3         1    4      1000         85.00
# 4         1      0      0      2         1    0      1000         81.79
# ...     ...    ...    ...    ...       ...  ...       ...           ...
# 5263      0      1      0      2         1    1       100        110.00
# 5264      1      0      0      2         1    1       100         85.00
# 5265      1      0      0      2         1    1       100         88.00
# 5266      1      0      0      2         1    1       100        105.00
# 5267      1      0      0      2         1    1       100         90.00
#
#       Distance  YearBuilt    Price
# 0         21.8       2012   990000
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[['Type1', 'Type2', 'Type3', 'Rooms', 'Bathroom', 'Car', 'Landsize', 'BuildingArea', 'Distance', 'YearBuilt']]
y = df['Price']

# %%
train_x = X[:round(5268*.8)]
train_y = y[:round(5268*.8)]

test_x = X[round(5268*.8):]
test_y = y[round(5268*.8):]

# %%
print(train_x)
# Out:
#       Type1  Type2  Type3  Rooms  Bathroom  Car  Landsize  BuildingArea  \
# 0         1      0      0      4         3    2      1001        315.00
# 1         1      0      0      5         4    2      1000        324.00
# 2         1      0      0      4         1    1      1000        203.00
# 3         1      0      0      3         1    4      1000         85.00
# 4         1      0      0      2         1    0      1000         81.79
# ...     ...    ...    ...    ...       ...  ...       ...           ...
# 4209      0      0      1      2         1    1       228        125.00
# 4210      1      0      0      2         1    2       228        110.00
# 4211      1      0      0      2         2    1       228        111.00
# 4212      1      0      0      2         1    1       228         87.00
# 4213      1      0      0      2         1    2       228         90.00
#
#       Distance  YearBuilt
# 0         21.8       2012
# 1         13.7       1950
# ...

# %%
model = linear_model.LinearRegression()
model.fit(train_x, train_y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
predictions = model.predict(test_x)

# %%
print(predictions[:5])
# Out:
# [ 562162.1062056   523069.03981568 1430030.80947077 1396241.69547117
#  1171890.98670508]

# %%
print(model.score(test_x, test_y))
# Out:
# 0.5898031214785835
