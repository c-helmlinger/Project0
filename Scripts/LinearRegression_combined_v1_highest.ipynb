# %% [markdown]
# # Introduction of Data

# %%
#!pip install matplotlib

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("/Users/jessicazhang/Desktop/data.csv")

# %%
df.columns
# Out:
# Index(['Type1', 'Type2', 'Type3', 'Rooms', 'Bathroom', 'Car', 'Landsize',
#        'BuildingArea', 'Distance', 'YearBuilt', 'Price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5267 entries, 0 to 5266
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Type1         5267 non-null   int64
#  1   Type2         5267 non-null   int64
#  2   Type3         5267 non-null   int64
#  3   Rooms         5267 non-null   int64
#  4   Bathroom      5267 non-null   int64
#  5   Car           5267 non-null   int64
#  6   Landsize      5267 non-null   int64
#  7   BuildingArea  5267 non-null   float64
#  8   Distance      5267 non-null   float64
#  9   YearBuilt     5267 non-null   int64
#  10  Price         5267 non-null   int64
# dtypes: float64(2), int64(9)
# memory usage: 452.8 KB

# %%
df.head()
# Out:
#    Type1  Type2  Type3  Rooms  Bathroom  Car  Landsize  BuildingArea  \
# 0      0      0      1      5         2    1       531        1022.0
# 1      1      0      0      3         1    1       532         934.0
# 2      1      0      0      3         1    1       792         792.0
# 3      1      0      0      5         3    2       836         789.0
# 4      1      0      0      3         1    2       713         720.0
#
#    Distance  YearBuilt    Price
# 0       5.6       1890  1975000
# 1      16.3       1980   580500
# 2      12.2       1950  1365000
# 3      24.8       2001  1100000
# 4       9.2       1950  1903000

# %%
df.describe()
# Out:
#              Type1        Type2        Type3        Rooms     Bathroom  \
# count  5267.000000  5267.000000  5267.000000  5267.000000  5267.000000
# mean      0.831403     0.079552     0.089045     3.209037     1.658629
# std       0.374431     0.270624     0.284836     0.841712     0.717665
# min       0.000000     0.000000     0.000000     1.000000     1.000000
# 25%       1.000000     0.000000     0.000000     3.000000     1.000000
# 50%       1.000000     0.000000     0.000000     3.000000     2.000000
# 75%       1.000000     0.000000     0.000000     4.000000     2.000000
# max       1.000000     1.000000     1.000000     8.000000     6.000000
#
#                Car     Landsize  BuildingArea     Distance    YearBuilt  \
# count  5267.000000  5267.000000   5267.000000  5267.000000  5267.000000
# mean      1.702487   469.215113    157.745611    10.983140  1960.385988
# std       0.970002   222.577387     76.400716     6.005211    38.936709
# min       0.000000   100.000000     51.000000     1.200000  1196.000000
# 25%       1.000000   267.000000    109.000000     7.000000  1930.000000
# 50%       2.000000   492.000000    138.000000    10.400000  1960.000000
# 75%       2.000000   648.000000    184.000000    13.700000  1995.000000
# max      10.000000  1001.000000   1022.000000    47.300000  2018.000000
#
#               Price
# count  5.267000e+03
# mean   1.170918e+06
# std    6.436500e+05
# min    1.310000e+05
# 25%    7.282500e+05
# 50%    1.000000e+06
# 75%    1.434250e+06
# max    6.400000e+06

# %%
df.shape
# Out:
# (5267, 11)

# %%
df.corr()
# Out:
#                  Type1     Type2     Type3     Rooms  Bathroom       Car  \
# Type1         1.000000 -0.652840 -0.694284  0.136550  0.067745  0.132703
# Type2        -0.652840  1.000000 -0.091914 -0.134708 -0.052765 -0.131907
# Type3        -0.694284 -0.091914  1.000000 -0.051515 -0.038921 -0.049120
# Rooms         0.136550 -0.134708 -0.051515  1.000000  0.589701  0.339706
# Bathroom      0.067745 -0.052765 -0.038921  0.589701  1.000000  0.271716
# Car           0.132703 -0.131907 -0.049120  0.339706  0.271716  1.000000
# Landsize      0.313577 -0.302551 -0.124758  0.433736  0.197296  0.398209
# BuildingArea  0.097762 -0.107199 -0.026663  0.601220  0.591952  0.284407
# Distance      0.133777 -0.122520 -0.059450  0.164903  0.069653  0.219398
# YearBuilt     0.025956 -0.002104 -0.032122  0.073263  0.236058  0.194966
# Price         0.052380 -0.051827 -0.019615  0.404541  0.436607  0.136808
#
#               Landsize  BuildingArea  Distance  YearBuilt     Price
# Type1         0.313577      0.097762  0.133777   0.025956  0.052380
# Type2        -0.302551     -0.107199 -0.122520  -0.002104 -0.051827
# Type3        -0.124758     -0.026663 -0.059450  -0.032122 -0.019615
# Rooms         0.433736      0.601220  0.164903   0.073263  0.404541
# Bathroom      0.197296      0.591952  0.069653   0.236058  0.436607
# Car           0.398209      0.284407  0.219398   0.194966  0.136808
# Landsize      1.000000      0.343027  0.353014   0.031417  0.223239
# BuildingArea  0.343027      1.000000  0.070258   0.155418  0.501773
# Distance      0.353014      0.070258  1.000000   0.394321 -0.335490
# YearBuilt     0.031417      0.155418  0.394321   1.000000 -0.286242
# Price         0.223239      0.501773 -0.335490  -0.286242  1.000000

# %% [markdown]
# # Data Visualisation

# %%
plt.style.use({'figure.figsize':(15,10)})

# %%
# test normal distribution
sns.distplot(df['Price'])
# Out:
# /Users/jessicazhang/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
# Show correlation
# scatterplot
sns.pairplot(df)

# %%
sns.heatmap(df.corr(), square=True, annot=True, cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
import seaborn as sns

# %%
# correlation matrix
corrmat = df.corr()
# choose the top four features
k = 4 # number of variables for heatmap
cols = corrmat.nlargest(k, 'Price')['Price'].index
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale = 1.25)
# cmap means the color, annot short for "annotation"
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size':10}, yticklabels=cols, xticklabels=cols.values, cmap="YlGnBu")
plt.show()

# %%
# size of the graph
plt.style.use({'figure.figsize':(10,8)})

# %%
# Single graph
plt.scatter(df['BuildingArea'], df['Price'])
plt.title('Building Area and Housing Price')
plt.xlabel('Building Size in Meters')
plt.ylabel('Housing Price')
plt.show()

# %%
# All the columns
for each in df.columns:
    plt.scatter(df[each], df['Price'])
    plt.xlabel(each)
    plt.ylabel("Melbourne Housing Price")
    plt.grid()
    plt.show()

# %%
# large skewness
print("Skewness:%f" %df['Price'].skew())
# Out:
# Skewness:2.003863

# %%
# show outliers
sns.lmplot(x='BuildingArea', y='Price', data=df)

# %%
# Delete outliers
drop_points = df.sort_values(by = "BuildingArea", ascending=False)[:1]["BuildingArea"]
drop_points_list = drop_points.index.tolist()
df.drop(drop_points_list, inplace=True)

# After finding the point on the graph, then you can delete it using excel.

# %%
# Boxplot
sns.boxplot(x='YearBuilt',y='Price',data=df)
# from the graphs, it shows little correlation
# Out:
# <AxesSubplot:xlabel='YearBuilt', ylabel='Price'>

# %%
# histogram
df.hist(bins=15)
# Out:
# array([[<AxesSubplot:title={'center':'Type1'}>,
#         <AxesSubplot:title={'center':'Type2'}>,
#         <AxesSubplot:title={'center':'Type3'}>],
#        [<AxesSubplot:title={'center':'Rooms'}>,
#         <AxesSubplot:title={'center':'Bathroom'}>,
#         <AxesSubplot:title={'center':'Car'}>],
#        [<AxesSubplot:title={'center':'Landsize'}>,
#         <AxesSubplot:title={'center':'BuildingArea'}>,
#         <AxesSubplot:title={'center':'Distance'}>],
#        [<AxesSubplot:title={'center':'YearBuilt'}>,
#         <AxesSubplot:title={'center':'Price'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# # Adding Columns

# %% [markdown]
# ## Single

# %% [markdown]
# ## 1. for x5^0.5

# %%
# x5 is the number of bathroom
# Bathroom_sqrt is the result of square of root

df['Bathroom_sqrt'] = np.sqrt(df['Bathroom'])
df.head()
# Out:
#    Type1  Type2  Type3  Rooms  Bathroom  Car  Landsize  BuildingArea  \
# 0      0      0      1      5         2    1       531        1022.0
# 1      1      0      0      3         1    1       532         934.0
# 2      1      0      0      3         1    1       792         792.0
# 3      1      0      0      5         3    2       836         789.0
# 4      1      0      0      3         1    2       713         720.0
#
#    Distance  YearBuilt    Price  Bathroom_sqrt
# 0       5.6       1890  1975000       1.414214
# 1      16.3       1980   580500       1.000000
# 2      12.2       1950  1365000       1.000000
# 3      24.8       2001  1100000       1.732051
# 4       9.2       1950  1903000       1.000000

# %% [markdown]
# ## 2. for x5^2

# %%
# Bathroom_sqr means Bathroom*Bathroom
# pow() means the square
# i.e. pow(4,2) = 4^2 = 16

df['Bathroom_sqr'] = pow(df['Bathroom'],2)
df.head()
# Out:
#    Type1  Type2  Type3  Rooms  Bathroom  Car  Landsize  BuildingArea  \
# 0      0      0      1      5         2    1       531        1022.0
# 1      1      0      0      3         1    1       532         934.0
# 2      1      0      0      3         1    1       792         792.0
# 3      1      0      0      5         3    2       836         789.0
# 4      1      0      0      3         1    2       713         720.0
#
#    Distance  YearBuilt    Price  Bathroom_sqr
# 0       5.6       1890  1975000             4
# 1      16.3       1980   580500             1
# 2      12.2       1950  1365000             1
# 3      24.8       2001  1100000             9
# 4       9.2       1950  1903000             1

# %% [markdown]
# ## 3. for x8^0.5

# %%
# x8 is the building area
# BuildingArea_sqr is the square root.

df['BuildingArea_sqrt'] = np.sqrt(df['BuildingArea'])
df.head()
# Out:
#    Type1  Type2  Type3  Rooms  Bathroom  Car  Landsize  BuildingArea  \
# 0      0      0      1      5         2    1       531        1022.0
# 1      1      0      0      3         1    1       532         934.0
# 2      1      0      0      3         1    1       792         792.0
# 3      1      0      0      5         3    2       836         789.0
# 4      1      0      0      3         1    2       713         720.0
#
#    Distance  YearBuilt    Price  BuildingArea_sqrt
# 0       5.6       1890  1975000          31.968735
# 1      16.3       1980   580500          30.561414
# 2      12.2       1950  1365000          28.142495
# 3      24.8       2001  1100000          28.089144
# 4       9.2       1950  1903000          26.832816

# %% [markdown]
# ## 4. for x8^2

# %%
# BuildingArea_sqr is the square result.

df['BuildingArea_sqr'] = pow(df['BuildingArea'],2)
df.head()
# Out:
#    Type1  Type2  Type3  Rooms  Bathroom  Car  Landsize  BuildingArea  \
# 0      0      0      1      5         2    1       531        1022.0
# 1      1      0      0      3         1    1       532         934.0
# 2      1      0      0      3         1    1       792         792.0
# 3      1      0      0      5         3    2       836         789.0
# 4      1      0      0      3         1    2       713         720.0
#
#    Distance  YearBuilt    Price  BuildingArea_sqr
# 0       5.6       1890  1975000         1044484.0
# 1      16.3       1980   580500          872356.0
# 2      12.2       1950  1365000          627264.0
# 3      24.8       2001  1100000          622521.0
# 4       9.2       1950  1903000          518400.0

# %% [markdown]
# ## 5. for x9^0.5

# %%
# x9 is the distance
# Distance_sqrt is the square root.

df['Distance_sqrt'] = np.sqrt(df['Distance'])
df.head()
# Out:
#    Type1  Type2  Type3  Rooms  Bathroom  Car  Landsize  BuildingArea  \
# 0      0      0      1      5         2    1       531        1022.0
# 1      1      0      0      3         1    1       532         934.0
# 2      1      0      0      3         1    1       792         792.0
# 3      1      0      0      5         3    2       836         789.0
# 4      1      0      0      3         1    2       713         720.0
#
#    Distance  YearBuilt    Price  Distance_sqrt
# 0       5.6       1890  1975000       2.366432
# 1      16.3       1980   580500       4.037326
# 2      12.2       1950  1365000       3.492850
# 3      24.8       2001  1100000       4.979960
# 4       9.2       1950  1903000       3.033150

# %% [markdown]
# ## 6. for x9^2

# %%
# Distance_sqr is the square.

df['Disctance_sqr'] = pow(df['Distance'],2)
df.head()
# Out:
#    Type1  Type2  Type3  Rooms  Bathroom  Car  Landsize  BuildingArea  \
# 0      0      0      1      5         2    1       531        1022.0
# 1      1      0      0      3         1    1       532         934.0
# 2      1      0      0      3         1    1       792         792.0
# 3      1      0      0      5         3    2       836         789.0
# 4      1      0      0      3         1    2       713         720.0
#
#    Distance  YearBuilt    Price  Disctance_sqr
# 0       5.6       1890  1975000          31.36
# 1      16.3       1980   580500         265.69
# 2      12.2       1950  1365000         148.84
# 3      24.8       2001  1100000         615.04
# 4       9.2       1950  1903000          84.64

# %% [markdown]
# ## 7. combination

# %%
# X8 is the building area
# pow() means the square of the number
# i.e. pow(4,2) = 4*4 = 16

df['BuildingArea_sqr'] = pow(df['BuildingArea'],2)
df['Distance_sqr'] = pow(df['Distance'], 2)
df['Bathroom_sqrt']=np.sqrt(df['Bathroom'])

df.head()
# Out:
#    Type1  Type2  Type3  Rooms  Bathroom  Car  Landsize  BuildingArea  \
# 0      0      0      1      5         2    1       531        1022.0
# 1      1      0      0      3         1    1       532         934.0
# 2      1      0      0      3         1    1       792         792.0
# 3      1      0      0      5         3    2       836         789.0
# 4      1      0      0      3         1    2       713         720.0
#
#    Distance  YearBuilt    Price  BuildingArea_sqr  Distance_sqr  Bathroom_sqrt
# 0       5.6       1890  1975000         1044484.0         31.36       1.414214
# 1      16.3       1980   580500          872356.0        265.69       1.000000
# 2      12.2       1950  1365000          627264.0        148.84       1.000000
# 3      24.8       2001  1100000          622521.0        615.04       1.732051
# 4       9.2       1950  1903000          518400.0         84.64       1.000000

# %% [markdown]
# # Train

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
# Drop the last column
X = df.drop(['Price'], axis = 1)

# %%
X
# Out:
#       Type1  Type2  Type3  Rooms  Bathroom  Car  Landsize  BuildingArea  \
# 0         0      0      1      5         2    1       531        1022.0
# 1         1      0      0      3         1    1       532         934.0
# 2         1      0      0      3         1    1       792         792.0
# 3         1      0      0      5         3    2       836         789.0
# 4         1      0      0      3         1    2       713         720.0
# ...     ...    ...    ...    ...       ...  ...       ...           ...
# 5262      1      0      0      1         1    1       480          53.0
# 5263      0      0      1      1         1    1       546          51.0
# 5264      1      0      0      2         1    1       483          51.0
# 5265      1      0      0      3         1    1       355          51.0
# 5266      1      0      0      1         1    1       106          51.0
#
#       Distance  YearBuilt  BuildingArea_sqr  Distance_sqr  Bathroom_sqrt
# 0          5.6       1890         1044484.0         31.36       1.414214
# 1         16.3       1980          872356.0        265.69       1.000000
# 2         12.2       1950          627264.0        148.84       1.000000
# 3         24.8       2001          622521.0        615.04       1.732051
# 4          9.2       1950          518400.0         84.64       1.000000
# ...        ...        ...               ...           ...            ...
# 5262       3.3       1930            2809.0         10.89       1.000000
# 5263       1.2       2000            2601.0          1.44       1.000000
# 5264       6.6       1970            2601.0         43.56       1.000000
# 5265      11.4       1960            2601.0        129.96       1.000000
# 5266      14.6       1990            2601.0        213.16       1.000000
#
# [5267 rows x 13 columns]

# %%
y = df['Price']

# %%
# Divide the data into two groups: training set and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=320, test_size=0.27)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred_class = model.predict(X_test)

# %%
y_pred_class
# Out:
# array([ 797654.82251206, 1295109.25741079,  898706.3553123 , ...,
#        1837570.53319213, 1632339.39909412,  719033.7225168 ])

# %%
metrics.mean_absolute_error(y_test, y_pred_class)
# Out:
# 286751.4690966534

# %%
# Note

# orginal score: 0.57022

#########################################SINGLE#############################################

# for x5
# (1) score: 0.56757
# (2) score: 0.57051

# for x8
# (3) score: 0.58560
# (4) score: 0.56198

# for x9
# (5) score: 0.58457
# (6) score: 0.58563

# %%
# The combined one gets the highest score: 0.60877...
model.score(X_test, y_test)
# Out:
# 0.6087749018727847

# %%
model.coef_
# Out:
# array([-3.86849937e+03,  1.87998353e+04, -1.49313360e+04,  7.35087214e+03,
#         5.97159297e+05,  6.44802766e+03,  4.65449121e+02,  6.78802848e+03,
#        -7.29959130e+04, -3.92393559e+03, -6.96674152e+00,  1.09790492e+03,
#        -1.12073916e+06])

# %%
# visualize gradient
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot(model.coef_)

# %%
import numpy as np

# %%
model.predict(X_test)
# Out:
# array([ 797654.82251206, 1295109.25741079,  898706.3553123 , ...,
#        1837570.53319213, 1632339.39909412,  719033.7225168 ])

# %%
y_test
# Out:
# 2187    1300000
# 3944    1005000
# 4631     750000
# 3196     861500
# 2635     645000
#          ...
# 70      3400000
# 2822    1460000
# 836     3270000
# 791      685000
# 2984     822500
# Name: Price, Length: 1423, dtype: int64

# %%
y_test.shape
# Out:
# (1423,)

# %%
from math import sqrt
print(sqrt(metrics.mean_squared_error(y_test, y_pred_class)))
# Out:
# 402988.8132417334

# %%
deviation = model.predict(X_test) - y_test

# %%
deviation
# Out:
# 2187   -5.023452e+05
# 3944    2.901093e+05
# 4631    1.487064e+05
# 3196   -1.423104e+05
# 2635    2.094901e+05
#             ...
# 70     -9.018587e+05
# 2822   -1.907375e+05
# 836    -1.432429e+06
# 791     9.473394e+05
# 2984   -1.034663e+05
# Name: Price, Length: 1423, dtype: float64

# %%
RMSE = np.sum(np.sqrt(deviation * deviation))/1317
RMSE
# Out:
# 309830.9343390568

# %%
import pandas as pd

# %%
result = {'prediction':model.predict(X_test)}

# %%
result_file = pd.DataFrame(result)

# %%
result_file.head()
# Out:
#      prediction
# 0  7.976548e+05
# 1  1.295109e+06
# 2  8.987064e+05
# 3  7.191896e+05
# 4  8.544901e+05

# %%
result_file.to_csv("Linear_Regression.csv")
